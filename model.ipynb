# %%
import tensorflow as tf
import tensorflow_hub as hub
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from tensorflow.keras.utils import get_file
from sklearn.metrics import roc_curve, auc, confusion_matrix, accuracy_score
from imblearn.metrics import sensitivity_score, specificity_score

import os
import glob
import zipfile
import random
#dataset from https://www.isic-archive.com/

# to get consistent results after multiple runs
tf.random.set_seed(7)
np.random.seed(7)
random.seed(7)

# 0 for benign, 1 for malignant
class_names = ["benign", "malignant"]

# %%
def download_and_extract_dataset():
  # dataset from https://github.com/udacity/dermatologist-ai
  # 5.3GB
  train_url = "https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/train.zip"
  # 824.5MB
  valid_url = "https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/valid.zip"
  # 5.1GB
  test_url  = "https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/test.zip"
  for i, download_link in enumerate([valid_url, train_url, test_url]):
    temp_file = f"temp{i}.zip"
    data_dir = get_file(origin=download_link, fname=os.path.join(os.getcwd(), temp_file))
    print("Extracting", download_link)
    with zipfile.ZipFile(data_dir, "r") as z:
      z.extractall("data")
    # remove the temp file
    os.remove(temp_file)


#download_and_extract_dataset()
# Out:
# Downloading data from https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/valid.zip
# 864538487/864538487 [==============================] - 21s 0us/step
# Extracting https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/valid.zip
# Downloading data from https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/train.zip
# 5736557430/5736557430 [==============================] - 136s 0us/step
# Extracting https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/train.zip
# Downloading data from https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/test.zip
# 5528640507/5528640507 [==============================] - 130s 0us/step
# Extracting https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/test.zip

# %%
# preparing data
# generate CSV metadata file to read img paths and labels from it
def generate_csv(folder, label2int):
    folder_name = os.path.basename(folder)
    labels = list(label2int)
    # generate CSV file
    df = pd.DataFrame(columns=["filepath", "label"])
    i = 0
    for label in labels:
        print("Reading", os.path.join(folder, label, "*"))
        for filepath in glob.glob(os.path.join(folder, label, "*")):
            df.loc[i] = [filepath, label2int[label]]
            i += 1
    output_file = f"{folder_name}.csv"
    print("Saving", output_file)
    df.to_csv(output_file)

# generate CSV files for all data portions, labeling nevus and seborrheic keratosis
# as 0 (benign), and melanoma as 1 (malignant)
generate_csv("data/train", {"nevus": 0, "seborrheic_keratosis": 0, "melanoma": 1})
generate_csv("data/valid", {"nevus": 0, "seborrheic_keratosis": 0, "melanoma": 1})
generate_csv("data/test", {"nevus": 0, "seborrheic_keratosis": 0, "melanoma": 1})
# Out:
# Reading data/train\nevus\*
# Reading data/train\seborrheic_keratosis\*
# Reading data/train\melanoma\*
# Saving train.csv
# Reading data/valid\nevus\*
# Reading data/valid\seborrheic_keratosis\*
# Reading data/valid\melanoma\*
# Saving valid.csv
# Reading data/test\nevus\*
# Reading data/test\seborrheic_keratosis\*
# Reading data/test\melanoma\*
# Saving test.csv

# %%
# loading data
train_metadata_filename = "train.csv"
valid_metadata_filename = "valid.csv"
# load CSV files as DataFrames
df_train = pd.read_csv(train_metadata_filename)
df_valid = pd.read_csv(valid_metadata_filename)
n_training_samples = len(df_train)
n_validation_samples = len(df_valid)
print("Number of training samples:", n_training_samples)
print("Number of validation samples:", n_validation_samples)
train_ds = tf.data.Dataset.from_tensor_slices((df_train["filepath"], df_train["label"]))
valid_ds = tf.data.Dataset.from_tensor_slices((df_valid["filepath"], df_valid["label"]))
# Out:
# Number of training samples: 2000
# Number of validation samples: 150

# %%
# preprocess data
def decode_img(img):
  # convert the compressed string to a 3D uint8 tensor
  img = tf.image.decode_jpeg(img, channels=3)
  # Use `convert_image_dtype` to convert to floats in the [0,1] range.
  img = tf.image.convert_image_dtype(img, tf.float32)
  # resize the image to the desired size.
  return tf.image.resize(img, [299, 299])


def process_path(filepath, label):
  # load the raw data from the file as a string
  img = tf.io.read_file(filepath)
  img = decode_img(img)
  return img, label



valid_ds = valid_ds.map(process_path)
train_ds = train_ds.map(process_path)
# test_ds = test_ds
for image, label in train_ds.take(1):
    print("Image shape:", image.shape)
    print("Label:", label.numpy())
# Out:
# Image shape: (299, 299, 3)
# Label: 0

# %%
# training parameters
batch_size = 64
optimizer = "rmsprop"

def prepare_for_training(ds, cache=True, batch_size=64, shuffle_buffer_size=1000):
  if cache:
    if isinstance(cache, str):
      ds = ds.cache(cache)
    else:
      ds = ds.cache()
  # shuffle the dataset
  ds = ds.shuffle(buffer_size=shuffle_buffer_size)
  # Repeat forever
  ds = ds.repeat()
  # split to batches
  ds = ds.batch(batch_size)
  # `prefetch` lets the dataset fetch batches in the background while the model
  # is training.
  ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
  return ds

valid_ds = prepare_for_training(valid_ds, batch_size=batch_size, cache="valid-cached-data")
train_ds = prepare_for_training(train_ds, batch_size=batch_size, cache="train-cached-data")

# %%
batch = next(iter(valid_ds))

def show_batch(batch):
  plt.figure(figsize=(12,12))
  for n in range(25):
      ax = plt.subplot(5,5,n+1)
      plt.imshow(batch[0][n])
      plt.title(class_names[batch[1][n].numpy()].title())
      plt.axis('off')
        
show_batch(batch)

# %%
# building the model
# InceptionV3 model & pre-trained weights
module_url = "https://tfhub.dev/google/tf2-preview/inception_v3/feature_vector/4"
m = tf.keras.Sequential([
    hub.KerasLayer(module_url, output_shape=[2048], trainable=False),
    tf.keras.layers.Dense(1, activation="sigmoid")
])

m.build([None, 299, 299, 3])
m.compile(loss="binary_crossentropy", optimizer=optimizer, metrics=["accuracy"])
m.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  keras_layer (KerasLayer)    (None, 2048)              21802784
#
#  dense (Dense)               (None, 1)                 2049
#
# =================================================================
# Total params: 21,804,833
# Trainable params: 2,049
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
model_name = f"benign-vs-malignant_{batch_size}_{optimizer}"
tensorboard = tf.keras.callbacks.TensorBoard(log_dir=os.path.join("logs", model_name))
# saves model checkpoint whenever we reach better weights
modelcheckpoint = tf.keras.callbacks.ModelCheckpoint(model_name + "_{val_loss:.3f}.h5", save_best_only=True, verbose=1)

history = m.fit(train_ds, validation_data=valid_ds, 
                steps_per_epoch=n_training_samples // batch_size, 
                validation_steps=n_validation_samples // batch_size, verbose=1, epochs=100,
                callbacks=[tensorboard, modelcheckpoint])
# Out:
# Epoch 1/100
# 31/31 [==============================] - ETA: 0s - loss: 0.4120 - accuracy: 0.8034
# Epoch 1: val_loss improved from inf to 0.50575, saving model to benign-vs-malignant_64_rmsprop_0.506.h5
# 31/31 [==============================] - 151s 4s/step - loss: 0.4120 - accuracy: 0.8034 - val_loss: 0.5057 - val_accuracy: 0.8047
# Epoch 2/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3927 - accuracy: 0.8095
# Epoch 2: val_loss improved from 0.50575 to 0.46311, saving model to benign-vs-malignant_64_rmsprop_0.463.h5
# 31/31 [==============================] - 96s 3s/step - loss: 0.3927 - accuracy: 0.8095 - val_loss: 0.4631 - val_accuracy: 0.8125
# Epoch 3/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3768 - accuracy: 0.8175
# Epoch 3: val_loss improved from 0.46311 to 0.45282, saving model to benign-vs-malignant_64_rmsprop_0.453.h5
# 31/31 [==============================] - 98s 3s/step - loss: 0.3768 - accuracy: 0.8175 - val_loss: 0.4528 - val_accuracy: 0.8047
# Epoch 4/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3670 - accuracy: 0.8251
# Epoch 4: val_loss did not improve from 0.45282
# 31/31 [==============================] - 93s 3s/step - loss: 0.3670 - accuracy: 0.8251 - val_loss: 0.4813 - val_accuracy: 0.7812
# Epoch 5/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3505 - accuracy: 0.8407
# Epoch 5: val_loss improved from 0.45282 to 0.44810, saving model to benign-vs-malignant_64_rmsprop_0.448.h5
# 31/31 [==============================] - 95s 3s/step - loss: 0.3505 - accuracy: 0.8407 - val_loss: 0.4481 - val_accuracy: 0.7969
# Epoch 6/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3463 - accuracy: 0.8422
# Epoch 6: val_loss did not improve from 0.44810
# 31/31 [==============================] - 96s 3s/step - loss: 0.3463 - accuracy: 0.8422 - val_loss: 0.4675 - val_accuracy: 0.7812
# Epoch 7/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3438 - accuracy: 0.8417
# Epoch 7: val_loss did not improve from 0.44810
# 31/31 [==============================] - 95s 3s/step - loss: 0.3438 - accuracy: 0.8417 - val_loss: 0.4790 - val_accuracy: 0.7578
# Epoch 8/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3348 - accuracy: 0.8412
# Epoch 8: val_loss improved from 0.44810 to 0.40806, saving model to benign-vs-malignant_64_rmsprop_0.408.h5
# 31/31 [==============================] - 91s 3s/step - loss: 0.3348 - accuracy: 0.8412 - val_loss: 0.4081 - val_accuracy: 0.8125
# Epoch 9/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3463 - accuracy: 0.8427
# Epoch 9: val_loss did not improve from 0.40806
# 31/31 [==============================] - 90s 3s/step - loss: 0.3463 - accuracy: 0.8427 - val_loss: 0.4572 - val_accuracy: 0.7656
# Epoch 10/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3125 - accuracy: 0.8614
# Epoch 10: val_loss did not improve from 0.40806
# 31/31 [==============================] - 91s 3s/step - loss: 0.3125 - accuracy: 0.8614 - val_loss: 0.4864 - val_accuracy: 0.7266
# Epoch 11/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3123 - accuracy: 0.8634
# Epoch 11: val_loss did not improve from 0.40806
# 31/31 [==============================] - 91s 3s/step - loss: 0.3123 - accuracy: 0.8634 - val_loss: 0.4199 - val_accuracy: 0.8281
# Epoch 12/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3280 - accuracy: 0.8564
# Epoch 12: val_loss did not improve from 0.40806
# 31/31 [==============================] - 91s 3s/step - loss: 0.3280 - accuracy: 0.8564 - val_loss: 0.4429 - val_accuracy: 0.8047
# Epoch 13/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3339 - accuracy: 0.8438
# Epoch 13: val_loss did not improve from 0.40806
# 31/31 [==============================] - 90s 3s/step - loss: 0.3339 - accuracy: 0.8438 - val_loss: 0.4380 - val_accuracy: 0.7969
# Epoch 14/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3075 - accuracy: 0.8634
# Epoch 14: val_loss did not improve from 0.40806
# 31/31 [==============================] - 89s 3s/step - loss: 0.3075 - accuracy: 0.8634 - val_loss: 0.4933 - val_accuracy: 0.7500
# Epoch 15/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3138 - accuracy: 0.8599
# Epoch 15: val_loss did not improve from 0.40806
# 31/31 [==============================] - 89s 3s/step - loss: 0.3138 - accuracy: 0.8599 - val_loss: 0.4372 - val_accuracy: 0.8203
# Epoch 16/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3190 - accuracy: 0.8574
# Epoch 16: val_loss did not improve from 0.40806
# 31/31 [==============================] - 89s 3s/step - loss: 0.3190 - accuracy: 0.8574 - val_loss: 0.4537 - val_accuracy: 0.7812
# Epoch 17/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3188 - accuracy: 0.8548
# Epoch 17: val_loss did not improve from 0.40806
# 31/31 [==============================] - 89s 3s/step - loss: 0.3188 - accuracy: 0.8548 - val_loss: 0.4711 - val_accuracy: 0.7656
# Epoch 18/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3038 - accuracy: 0.8684
# Epoch 18: val_loss did not improve from 0.40806
# 31/31 [==============================] - 90s 3s/step - loss: 0.3038 - accuracy: 0.8684 - val_loss: 0.5222 - val_accuracy: 0.7031
# Epoch 19/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3118 - accuracy: 0.8634
# Epoch 19: val_loss did not improve from 0.40806
# 31/31 [==============================] - 89s 3s/step - loss: 0.3118 - accuracy: 0.8634 - val_loss: 0.4276 - val_accuracy: 0.7891
# Epoch 20/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2917 - accuracy: 0.8700
# Epoch 20: val_loss did not improve from 0.40806
# 31/31 [==============================] - 90s 3s/step - loss: 0.2917 - accuracy: 0.8700 - val_loss: 0.4423 - val_accuracy: 0.7969
# Epoch 21/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2985 - accuracy: 0.8684
# Epoch 21: val_loss did not improve from 0.40806
# 31/31 [==============================] - 89s 3s/step - loss: 0.2985 - accuracy: 0.8684 - val_loss: 0.4441 - val_accuracy: 0.8047
# Epoch 22/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2984 - accuracy: 0.8720
# Epoch 22: val_loss did not improve from 0.40806
# 31/31 [==============================] - 89s 3s/step - loss: 0.2984 - accuracy: 0.8720 - val_loss: 0.4290 - val_accuracy: 0.7891
# Epoch 23/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2937 - accuracy: 0.8720
# Epoch 23: val_loss improved from 0.40806 to 0.39913, saving model to benign-vs-malignant_64_rmsprop_0.399.h5
# 31/31 [==============================] - 91s 3s/step - loss: 0.2937 - accuracy: 0.8720 - val_loss: 0.3991 - val_accuracy: 0.8203
# Epoch 24/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2888 - accuracy: 0.8679
# Epoch 24: val_loss did not improve from 0.39913
# 31/31 [==============================] - 95s 3s/step - loss: 0.2888 - accuracy: 0.8679 - val_loss: 0.4404 - val_accuracy: 0.7969
# Epoch 25/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2905 - accuracy: 0.8816
# Epoch 25: val_loss improved from 0.39913 to 0.39775, saving model to benign-vs-malignant_64_rmsprop_0.398.h5
# 31/31 [==============================] - 94s 3s/step - loss: 0.2905 - accuracy: 0.8816 - val_loss: 0.3978 - val_accuracy: 0.8359
# Epoch 26/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2991 - accuracy: 0.8720
# Epoch 26: val_loss did not improve from 0.39775
# 31/31 [==============================] - 92s 3s/step - loss: 0.2991 - accuracy: 0.8720 - val_loss: 0.4284 - val_accuracy: 0.8125
# Epoch 27/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2854 - accuracy: 0.8730
# Epoch 27: val_loss did not improve from 0.39775
# 31/31 [==============================] - 92s 3s/step - loss: 0.2854 - accuracy: 0.8730 - val_loss: 0.4328 - val_accuracy: 0.8125
# Epoch 28/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2749 - accuracy: 0.8836
# Epoch 28: val_loss did not improve from 0.39775
# 31/31 [==============================] - 92s 3s/step - loss: 0.2749 - accuracy: 0.8836 - val_loss: 0.4281 - val_accuracy: 0.8516
# Epoch 29/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3025 - accuracy: 0.8594
# Epoch 29: val_loss did not improve from 0.39775
# 31/31 [==============================] - 92s 3s/step - loss: 0.3025 - accuracy: 0.8594 - val_loss: 0.4868 - val_accuracy: 0.8203
# Epoch 30/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2792 - accuracy: 0.8775
# Epoch 30: val_loss did not improve from 0.39775
# 31/31 [==============================] - 92s 3s/step - loss: 0.2792 - accuracy: 0.8775 - val_loss: 0.4662 - val_accuracy: 0.7891
# Epoch 31/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2785 - accuracy: 0.8800
# Epoch 31: val_loss did not improve from 0.39775
# 31/31 [==============================] - 92s 3s/step - loss: 0.2785 - accuracy: 0.8800 - val_loss: 0.4480 - val_accuracy: 0.7969
# Epoch 32/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2823 - accuracy: 0.8826
# Epoch 32: val_loss did not improve from 0.39775
# 31/31 [==============================] - 90s 3s/step - loss: 0.2823 - accuracy: 0.8826 - val_loss: 0.4695 - val_accuracy: 0.7891
# Epoch 33/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2637 - accuracy: 0.8886
# Epoch 33: val_loss did not improve from 0.39775
# 31/31 [==============================] - 89s 3s/step - loss: 0.2637 - accuracy: 0.8886 - val_loss: 0.4699 - val_accuracy: 0.7891
# Epoch 34/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2752 - accuracy: 0.8795
# Epoch 34: val_loss did not improve from 0.39775
# 31/31 [==============================] - 89s 3s/step - loss: 0.2752 - accuracy: 0.8795 - val_loss: 0.4513 - val_accuracy: 0.7891
# Epoch 35/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2812 - accuracy: 0.8745
# Epoch 35: val_loss did not improve from 0.39775
# 31/31 [==============================] - 89s 3s/step - loss: 0.2812 - accuracy: 0.8745 - val_loss: 0.4407 - val_accuracy: 0.8125
# Epoch 36/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2736 - accuracy: 0.8836
# Epoch 36: val_loss did not improve from 0.39775
# 31/31 [==============================] - 89s 3s/step - loss: 0.2736 - accuracy: 0.8836 - val_loss: 0.4632 - val_accuracy: 0.7812
# Epoch 37/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2791 - accuracy: 0.8790
# Epoch 37: val_loss did not improve from 0.39775
# 31/31 [==============================] - 89s 3s/step - loss: 0.2791 - accuracy: 0.8790 - val_loss: 0.4594 - val_accuracy: 0.8047
# Epoch 38/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2815 - accuracy: 0.8805
# Epoch 38: val_loss did not improve from 0.39775
# 31/31 [==============================] - 89s 3s/step - loss: 0.2815 - accuracy: 0.8805 - val_loss: 0.4734 - val_accuracy: 0.7578
# Epoch 39/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2617 - accuracy: 0.8841
# Epoch 39: val_loss did not improve from 0.39775
# 31/31 [==============================] - 89s 3s/step - loss: 0.2617 - accuracy: 0.8841 - val_loss: 0.4022 - val_accuracy: 0.8438
# Epoch 40/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2632 - accuracy: 0.8997
# Epoch 40: val_loss did not improve from 0.39775
# 31/31 [==============================] - 89s 3s/step - loss: 0.2632 - accuracy: 0.8997 - val_loss: 0.4572 - val_accuracy: 0.8047
# Epoch 41/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2778 - accuracy: 0.8856
# Epoch 41: val_loss did not improve from 0.39775
# 31/31 [==============================] - 89s 3s/step - loss: 0.2778 - accuracy: 0.8856 - val_loss: 0.4297 - val_accuracy: 0.8281
# Epoch 42/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2716 - accuracy: 0.8836
# Epoch 42: val_loss did not improve from 0.39775
# 31/31 [==============================] - 90s 3s/step - loss: 0.2716 - accuracy: 0.8836 - val_loss: 0.4489 - val_accuracy: 0.8125
# Epoch 43/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2733 - accuracy: 0.8871
# Epoch 43: val_loss did not improve from 0.39775
# 31/31 [==============================] - 89s 3s/step - loss: 0.2733 - accuracy: 0.8871 - val_loss: 0.4681 - val_accuracy: 0.8047
# Epoch 44/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2647 - accuracy: 0.8891
# Epoch 44: val_loss did not improve from 0.39775
# 31/31 [==============================] - 89s 3s/step - loss: 0.2647 - accuracy: 0.8891 - val_loss: 0.4351 - val_accuracy: 0.8047
# Epoch 45/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2729 - accuracy: 0.8810
# Epoch 45: val_loss did not improve from 0.39775
# 31/31 [==============================] - 89s 3s/step - loss: 0.2729 - accuracy: 0.8810 - val_loss: 0.4161 - val_accuracy: 0.8125
# Epoch 46/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2471 - accuracy: 0.8987
# Epoch 46: val_loss did not improve from 0.39775
# 31/31 [==============================] - 40502s 1350s/step - loss: 0.2471 - accuracy: 0.8987 - val_loss: 0.4480 - val_accuracy: 0.8281
# Epoch 47/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2748 - accuracy: 0.8795
# Epoch 47: val_loss did not improve from 0.39775
# 31/31 [==============================] - 91s 3s/step - loss: 0.2748 - accuracy: 0.8795 - val_loss: 0.4399 - val_accuracy: 0.8125
# Epoch 48/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2621 - accuracy: 0.8906
# Epoch 48: val_loss did not improve from 0.39775
# 31/31 [==============================] - 95s 3s/step - loss: 0.2621 - accuracy: 0.8906 - val_loss: 0.4610 - val_accuracy: 0.8047
# Epoch 49/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2648 - accuracy: 0.8841
# Epoch 49: val_loss improved from 0.39775 to 0.37742, saving model to benign-vs-malignant_64_rmsprop_0.377.h5
# 31/31 [==============================] - 101s 3s/step - loss: 0.2648 - accuracy: 0.8841 - val_loss: 0.3774 - val_accuracy: 0.8281
# Epoch 50/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2482 - accuracy: 0.8957
# Epoch 50: val_loss did not improve from 0.37742
# 31/31 [==============================] - 90s 3s/step - loss: 0.2482 - accuracy: 0.8957 - val_loss: 0.4123 - val_accuracy: 0.8359
# Epoch 51/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2574 - accuracy: 0.8931
# Epoch 51: val_loss did not improve from 0.37742
# 31/31 [==============================] - 89s 3s/step - loss: 0.2574 - accuracy: 0.8931 - val_loss: 0.4687 - val_accuracy: 0.7969
# Epoch 52/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2521 - accuracy: 0.9052
# Epoch 52: val_loss did not improve from 0.37742
# 31/31 [==============================] - 90s 3s/step - loss: 0.2521 - accuracy: 0.9052 - val_loss: 0.4557 - val_accuracy: 0.8203
# Epoch 53/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2549 - accuracy: 0.8947
# Epoch 53: val_loss did not improve from 0.37742
# 31/31 [==============================] - 90s 3s/step - loss: 0.2549 - accuracy: 0.8947 - val_loss: 0.4355 - val_accuracy: 0.8203
# Epoch 54/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2624 - accuracy: 0.8876
# Epoch 54: val_loss did not improve from 0.37742
# 31/31 [==============================] - 89s 3s/step - loss: 0.2624 - accuracy: 0.8876 - val_loss: 0.4074 - val_accuracy: 0.8281
# Epoch 55/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2551 - accuracy: 0.8947
# Epoch 55: val_loss did not improve from 0.37742
# 31/31 [==============================] - 93s 3s/step - loss: 0.2551 - accuracy: 0.8947 - val_loss: 0.4904 - val_accuracy: 0.8047
# Epoch 56/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2450 - accuracy: 0.8992
# Epoch 56: val_loss did not improve from 0.37742
# 31/31 [==============================] - 97s 3s/step - loss: 0.2450 - accuracy: 0.8992 - val_loss: 0.4490 - val_accuracy: 0.8203
# Epoch 57/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2451 - accuracy: 0.8957
# Epoch 57: val_loss did not improve from 0.37742
# 31/31 [==============================] - 97s 3s/step - loss: 0.2451 - accuracy: 0.8957 - val_loss: 0.4708 - val_accuracy: 0.7891
# Epoch 58/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2442 - accuracy: 0.9002
# Epoch 58: val_loss did not improve from 0.37742
# 31/31 [==============================] - 95s 3s/step - loss: 0.2442 - accuracy: 0.9002 - val_loss: 0.4036 - val_accuracy: 0.8281
# Epoch 59/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2454 - accuracy: 0.8987
# Epoch 59: val_loss did not improve from 0.37742
# 31/31 [==============================] - 92s 3s/step - loss: 0.2454 - accuracy: 0.8987 - val_loss: 0.4100 - val_accuracy: 0.8359
# Epoch 60/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2495 - accuracy: 0.8906
# Epoch 60: val_loss did not improve from 0.37742
# 31/31 [==============================] - 92s 3s/step - loss: 0.2495 - accuracy: 0.8906 - val_loss: 0.4651 - val_accuracy: 0.7812
# Epoch 61/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2607 - accuracy: 0.8942
# Epoch 61: val_loss did not improve from 0.37742
# 31/31 [==============================] - 92s 3s/step - loss: 0.2607 - accuracy: 0.8942 - val_loss: 0.4617 - val_accuracy: 0.7578
# Epoch 62/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2478 - accuracy: 0.8977
# Epoch 62: val_loss did not improve from 0.37742
# 31/31 [==============================] - 92s 3s/step - loss: 0.2478 - accuracy: 0.8977 - val_loss: 0.5055 - val_accuracy: 0.7812
# Epoch 63/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2571 - accuracy: 0.8921
# Epoch 63: val_loss did not improve from 0.37742
# 31/31 [==============================] - 92s 3s/step - loss: 0.2571 - accuracy: 0.8921 - val_loss: 0.4629 - val_accuracy: 0.8125
# Epoch 64/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2367 - accuracy: 0.9042
# Epoch 64: val_loss did not improve from 0.37742
# 31/31 [==============================] - 91s 3s/step - loss: 0.2367 - accuracy: 0.9042 - val_loss: 0.4584 - val_accuracy: 0.8125
# Epoch 65/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2525 - accuracy: 0.8921
# Epoch 65: val_loss did not improve from 0.37742
# 31/31 [==============================] - 91s 3s/step - loss: 0.2525 - accuracy: 0.8921 - val_loss: 0.4417 - val_accuracy: 0.8281
# Epoch 66/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2266 - accuracy: 0.9098
# Epoch 66: val_loss did not improve from 0.37742
# 31/31 [==============================] - 92s 3s/step - loss: 0.2266 - accuracy: 0.9098 - val_loss: 0.4278 - val_accuracy: 0.8438
# Epoch 67/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2329 - accuracy: 0.9052
# Epoch 67: val_loss did not improve from 0.37742
# 31/31 [==============================] - 93s 3s/step - loss: 0.2329 - accuracy: 0.9052 - val_loss: 0.4405 - val_accuracy: 0.8359
# Epoch 68/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2504 - accuracy: 0.8987
# Epoch 68: val_loss did not improve from 0.37742
# 31/31 [==============================] - 93s 3s/step - loss: 0.2504 - accuracy: 0.8987 - val_loss: 0.4660 - val_accuracy: 0.8203
# Epoch 69/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2368 - accuracy: 0.9078
# Epoch 69: val_loss did not improve from 0.37742
# 31/31 [==============================] - 93s 3s/step - loss: 0.2368 - accuracy: 0.9078 - val_loss: 0.4990 - val_accuracy: 0.8125
# Epoch 70/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2457 - accuracy: 0.8957
# Epoch 70: val_loss did not improve from 0.37742
# 31/31 [==============================] - 92s 3s/step - loss: 0.2457 - accuracy: 0.8957 - val_loss: 0.4508 - val_accuracy: 0.8125
# Epoch 71/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2337 - accuracy: 0.9062
# Epoch 71: val_loss did not improve from 0.37742
# 31/31 [==============================] - 92s 3s/step - loss: 0.2337 - accuracy: 0.9062 - val_loss: 0.5614 - val_accuracy: 0.8125
# Epoch 72/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2444 - accuracy: 0.8987
# Epoch 72: val_loss did not improve from 0.37742
# 31/31 [==============================] - 92s 3s/step - loss: 0.2444 - accuracy: 0.8987 - val_loss: 0.5148 - val_accuracy: 0.8125
# Epoch 73/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2429 - accuracy: 0.8962
# Epoch 73: val_loss did not improve from 0.37742
# 31/31 [==============================] - 93s 3s/step - loss: 0.2429 - accuracy: 0.8962 - val_loss: 0.5881 - val_accuracy: 0.8281
# Epoch 74/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2399 - accuracy: 0.9093
# Epoch 74: val_loss did not improve from 0.37742
# 31/31 [==============================] - 90s 3s/step - loss: 0.2399 - accuracy: 0.9093 - val_loss: 0.6806 - val_accuracy: 0.7969
# Epoch 75/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2248 - accuracy: 0.9078
# Epoch 75: val_loss did not improve from 0.37742
# 31/31 [==============================] - 88s 3s/step - loss: 0.2248 - accuracy: 0.9078 - val_loss: 0.6372 - val_accuracy: 0.8281
# Epoch 76/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2360 - accuracy: 0.9022
# Epoch 76: val_loss did not improve from 0.37742
# 31/31 [==============================] - 90s 3s/step - loss: 0.2360 - accuracy: 0.9022 - val_loss: 0.6583 - val_accuracy: 0.8125
# Epoch 77/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2447 - accuracy: 0.8992
# Epoch 77: val_loss did not improve from 0.37742
# 31/31 [==============================] - 90s 3s/step - loss: 0.2447 - accuracy: 0.8992 - val_loss: 0.6733 - val_accuracy: 0.8047
# Epoch 78/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2275 - accuracy: 0.9002
# Epoch 78: val_loss did not improve from 0.37742
# 31/31 [==============================] - 92s 3s/step - loss: 0.2275 - accuracy: 0.9002 - val_loss: 0.7240 - val_accuracy: 0.8047
# Epoch 79/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2255 - accuracy: 0.9098
# Epoch 79: val_loss did not improve from 0.37742
# 31/31 [==============================] - 93s 3s/step - loss: 0.2255 - accuracy: 0.9098 - val_loss: 0.8446 - val_accuracy: 0.7891
# Epoch 80/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2276 - accuracy: 0.9052
# Epoch 80: val_loss did not improve from 0.37742
# 31/31 [==============================] - 94s 3s/step - loss: 0.2276 - accuracy: 0.9052 - val_loss: 0.7547 - val_accuracy: 0.8125
# Epoch 81/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2385 - accuracy: 0.9002
# Epoch 81: val_loss did not improve from 0.37742
# 31/31 [==============================] - 95s 3s/step - loss: 0.2385 - accuracy: 0.9002 - val_loss: 0.8948 - val_accuracy: 0.7812
# Epoch 82/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2253 - accuracy: 0.9128
# Epoch 82: val_loss did not improve from 0.37742
# 31/31 [==============================] - 93s 3s/step - loss: 0.2253 - accuracy: 0.9128 - val_loss: 0.8685 - val_accuracy: 0.7891
# Epoch 83/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2355 - accuracy: 0.9057
# Epoch 83: val_loss did not improve from 0.37742
# 31/31 [==============================] - 95s 3s/step - loss: 0.2355 - accuracy: 0.9057 - val_loss: 0.8611 - val_accuracy: 0.8047
# Epoch 84/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2359 - accuracy: 0.9052
# Epoch 84: val_loss did not improve from 0.37742
# 31/31 [==============================] - 95s 3s/step - loss: 0.2359 - accuracy: 0.9052 - val_loss: 0.9500 - val_accuracy: 0.7891
# Epoch 85/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2359 - accuracy: 0.8997
# Epoch 85: val_loss did not improve from 0.37742
# 31/31 [==============================] - 94s 3s/step - loss: 0.2359 - accuracy: 0.8997 - val_loss: 0.6864 - val_accuracy: 0.8359
# Epoch 86/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2272 - accuracy: 0.9093
# Epoch 86: val_loss did not improve from 0.37742
# 31/31 [==============================] - 95s 3s/step - loss: 0.2272 - accuracy: 0.9093 - val_loss: 0.9629 - val_accuracy: 0.7891
# Epoch 87/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2280 - accuracy: 0.9062
# Epoch 87: val_loss did not improve from 0.37742
# 31/31 [==============================] - 92s 3s/step - loss: 0.2280 - accuracy: 0.9062 - val_loss: 0.9259 - val_accuracy: 0.8047
# Epoch 88/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2241 - accuracy: 0.9143
# Epoch 88: val_loss did not improve from 0.37742
# 31/31 [==============================] - 92s 3s/step - loss: 0.2241 - accuracy: 0.9143 - val_loss: 0.9517 - val_accuracy: 0.7891
# Epoch 89/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2372 - accuracy: 0.9108
# Epoch 89: val_loss did not improve from 0.37742
# 31/31 [==============================] - 91s 3s/step - loss: 0.2372 - accuracy: 0.9108 - val_loss: 0.8743 - val_accuracy: 0.8125
# Epoch 90/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2286 - accuracy: 0.9037
# Epoch 90: val_loss did not improve from 0.37742
# 31/31 [==============================] - 92s 3s/step - loss: 0.2286 - accuracy: 0.9037 - val_loss: 0.8841 - val_accuracy: 0.7969
# Epoch 91/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2291 - accuracy: 0.9118
# Epoch 91: val_loss did not improve from 0.37742
# 31/31 [==============================] - 91s 3s/step - loss: 0.2291 - accuracy: 0.9118 - val_loss: 0.8129 - val_accuracy: 0.8125
# Epoch 92/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2290 - accuracy: 0.9042
# Epoch 92: val_loss did not improve from 0.37742
# 31/31 [==============================] - 90s 3s/step - loss: 0.2290 - accuracy: 0.9042 - val_loss: 0.8767 - val_accuracy: 0.7969
# Epoch 93/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2415 - accuracy: 0.9002
# Epoch 93: val_loss did not improve from 0.37742
# 31/31 [==============================] - 90s 3s/step - loss: 0.2415 - accuracy: 0.9002 - val_loss: 0.8113 - val_accuracy: 0.7891
# Epoch 94/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2219 - accuracy: 0.9088
# Epoch 94: val_loss did not improve from 0.37742
# 31/31 [==============================] - 90s 3s/step - loss: 0.2219 - accuracy: 0.9088 - val_loss: 0.8272 - val_accuracy: 0.7969
# Epoch 95/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2296 - accuracy: 0.9057
# Epoch 95: val_loss did not improve from 0.37742
# 31/31 [==============================] - 90s 3s/step - loss: 0.2296 - accuracy: 0.9057 - val_loss: 0.8527 - val_accuracy: 0.7969
# Epoch 96/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2245 - accuracy: 0.9088
# Epoch 96: val_loss did not improve from 0.37742
# 31/31 [==============================] - 90s 3s/step - loss: 0.2245 - accuracy: 0.9088 - val_loss: 0.8872 - val_accuracy: 0.7812
# Epoch 97/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2260 - accuracy: 0.9133
# Epoch 97: val_loss did not improve from 0.37742
# 31/31 [==============================] - 90s 3s/step - loss: 0.2260 - accuracy: 0.9133 - val_loss: 0.8739 - val_accuracy: 0.7891
# Epoch 98/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2152 - accuracy: 0.9123
# Epoch 98: val_loss did not improve from 0.37742
# 31/31 [==============================] - 89s 3s/step - loss: 0.2152 - accuracy: 0.9123 - val_loss: 0.8835 - val_accuracy: 0.8047
# Epoch 99/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2226 - accuracy: 0.9168
# Epoch 99: val_loss did not improve from 0.37742
# 31/31 [==============================] - 89s 3s/step - loss: 0.2226 - accuracy: 0.9168 - val_loss: 0.7025 - val_accuracy: 0.8125
# Epoch 100/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2291 - accuracy: 0.9088
# Epoch 100: val_loss did not improve from 0.37742
# 31/31 [==============================] - 88s 3s/step - loss: 0.2291 - accuracy: 0.9088 - val_loss: 0.8554 - val_accuracy: 0.7891

# %%
# evaluation
# load testing set
test_metadata_filename = "test.csv"
df_test = pd.read_csv(test_metadata_filename)
n_testing_samples = len(df_test)
print("Number of testing samples:", n_testing_samples)
test_ds = tf.data.Dataset.from_tensor_slices((df_test["filepath"], df_test["label"]))

def prepare_for_testing(ds, cache=True, shuffle_buffer_size=1000):
  if cache:
    if isinstance(cache, str):
      ds = ds.cache(cache)
    else:
      ds = ds.cache()
  ds = ds.shuffle(buffer_size=shuffle_buffer_size)
  return ds

test_ds = test_ds.map(process_path)
test_ds = prepare_for_testing(test_ds, cache="test-cached-data")
# Out:
# Number of testing samples: 600

# %%
# convert testing set to numpy array to fit in memory (don't do that when testing
# set is too large)
y_test = np.zeros((n_testing_samples,))
X_test = np.zeros((n_testing_samples, 299, 299, 3))
for i, (img, label) in enumerate(test_ds.take(n_testing_samples)):
  # print(img.shape, label.shape)
  X_test[i] = img
  y_test[i] = label.numpy()

print("y_test.shape:", y_test.shape)
# Out:
# y_test.shape: (600,)

# %%
m.load_weights("benign-vs-malignant_64_rmsprop_0.377.h5")

# %%
print("Evaluating the model...")
loss, accuracy = m.evaluate(X_test, y_test, verbose=0)
print("Loss:", loss, "  Accuracy:", accuracy)

#not bad, but accuracy could be 'biased' such that if it only labeled cancers as benign, we would achieve same accuracy
# Out:
# Evaluating the model...
# Loss: 0.45819467306137085   Accuracy: 0.7983333468437195

# %%
def get_predictions(threshold=None):
  """
  Returns predictions for binary classification given `threshold`
  For instance, if threshold is 0.3, then it'll output 1 (malignant) for that sample if
  the probability of 1 is 30% or more (instead of 50%)
  """
  y_pred = m.predict(X_test)
  if not threshold:
    threshold = 0.5
  result = np.zeros((n_testing_samples,))
  for i in range(n_testing_samples):
    # test melanoma probability
    if y_pred[i][0] >= threshold:
      result[i] = 1
    # else, it's 0 (benign)
  return result

threshold = 0.23
# get predictions with 23% threshold
# which means if the model is 23% sure or more that is malignant,
# it's assigned as malignant, otherwise it's benign
y_pred = get_predictions(threshold)
accuracy_after = accuracy_score(y_test, y_pred)
print("Accuracy after setting the threshold:", accuracy_after)
# Out:
# 19/19 [==============================] - 28s 1s/step
# Accuracy after setting the threshold: 0.75

# %%
def plot_confusion_matrix(y_test, y_pred):
  cmn = confusion_matrix(y_test, y_pred)
  # Normalise
  cmn = cmn.astype('float') / cmn.sum(axis=1)[:, np.newaxis]
  # print it
  print(cmn)
  fig, ax = plt.subplots(figsize=(10,10))
  sns.heatmap(cmn, annot=True, fmt='.2f', 
              xticklabels=[f"pred_{c}" for c in class_names], 
              yticklabels=[f"true_{c}" for c in class_names],
              cmap="Blues"
              )
  plt.ylabel('Actual')
  plt.xlabel('Predicted')
  # plot the resulting confusion matrix
  plt.show()

plot_confusion_matrix(y_test, y_pred)
# Out:
# [[0.79089027 0.20910973]
#  [0.41880342 0.58119658]]

# %%
# a function given a function, it predicts the class of the image
def predict_image_class(img_path, model, threshold=0.5):
  img = tf.keras.preprocessing.image.load_img(img_path, target_size=(299, 299))
  img = tf.keras.preprocessing.image.img_to_array(img)
  img = tf.expand_dims(img, 0) # Create a batch
  img = tf.keras.applications.inception_v3.preprocess_input(img)
  img = tf.image.convert_image_dtype(img, tf.float32)
  predictions = model.predict(img)
  score = predictions.squeeze()
  if score >= threshold:
    print(f"This image is {100 * score:.2f}% malignant.")
  else:
    print(f"This image is {100 * (1 - score):.2f}% benign.")
  plt.imshow(img[0])
  plt.axis('off')
  plt.show()

# %%
predict_image_class("data/test/melanoma/ISIC_0013767.jpg", m)
# Out:
# 1/1 [==============================] - 0s 90ms/step
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# This image is 55.22% benign.
